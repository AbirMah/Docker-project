# %%
import librosa.display
import scipy.io.wavfile as wavfile
import numpy
import os.path
from os import walk
from scipy import stats
import numpy as np
import librosa 
import numpy as np
from scipy.stats import norm
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix
#from pycm import *

def extractMelSpectrogram_features(folder):
    hop_length = 512
    n_fft = 2048
    n_mels = 128
    types = ["blues", "classical", "country", "disco", "hiphop", "metal", "pop", "reggae", "rock"]
    a = []
    b = []
    for nametype in types:
        _wavs = []
        wavs_duration = []
        for (_,_,filenames) in walk(folder+nametype+"/"):
            _wavs.extend(filenames)
            break
        Mel_Spectrogram = []
        for _wav in _wavs:
            # read audio samples
            if(".wav" in _wav): 
                file = folder +nametype+"/"+_wav
                print ("-"+file)
                signal, rate = librosa.load(file)  
                #The Mel Spectrogram
                S = librosa.feature.melspectrogram(signal, sr=rate, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
                S_DB = librosa.power_to_db(S, ref=np.max)
                #Mel_Spectrogram.append(S_DB)
                #print (S_DB)
                S_DB = S_DB.flatten()[:1200]
                a.append(S_DB)
                if(nametype == "blues"):
                    b.append("blues")
                elif (nametype == "classical"):
                    b.append("classical")
                elif (nametype == "country"):
                    b.append("country")
                elif (nametype == "disco"):
                    b.append("disco")
                elif (nametype == "hiphop"):
                    b.append("hiphop")
                
                elif (nametype == "metal"):
                    b.append("metal")
                elif (nametype == "pop"):
                    b.append("pop")
                elif (nametype == "reggae"):
                    b.append("reggae")
                elif (nametype == "rock"):
                    b.append("rock")
    pickle.dump(a, open(folder+'mel_features_svm_a.data', 'wb'))
    pickle.dump(b, open(folder+'mel_features_svm_b.data', 'wb'))
    #pickle.dump(clf, open(folder+'svm.data', 'wb'))

    
    return a, b

def getPrediction(folder, clf):
    hop_length = 512
    n_fft = 2048
    n_mels = 128
    types = ["blues", "classical", "country", "disco", "hiphop", "metal", "pop", "reggae", "rock"]
    list_y_true = []
    list_y_pred = []
    for nametype in types:
        _wavs = []
        wavs_duration = []
        for (_,_,filenames) in walk(folder+nametype+"/"):
            _wavs.extend(filenames)
            break
        for _wav in _wavs:
            # read audio samples
            if(".wav" in _wav): 
                file = folder +nametype+"/"+_wav
                print ("-"+file)
                signal, rate = librosa.load(file)  
                #The Mel Spectrogram
                S = librosa.feature.melspectrogram(signal, sr=rate, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
                S_DB = librosa.power_to_db(S, ref=np.max)
                S_DB = S_DB.flatten()[:1200]
                y_pred = clf.predict([S_DB])[0]
                if(nametype=="blue"):
                    y_true = "blue"
                elif (nametype == "classical"):
                    y_true = "classical"
                elif (nametype == "country"):
                    y_true = "country"
                elif (nametype == "disco"):
                    y_true = "disco"
                elif (nametype == "hiphop"):
                    y_true = "hiphop"
               
                elif (nametype == "metal"):
                    y_true = "metal"
                elif (nametype == "pop"):
                    y_true = "pop"
                elif (nametype == "reggae"):
                    y_true = "reggae"
                else :
                    y_true = "rock"
                list_y_true.append(y_true)
                list_y_pred.append(y_pred)
                print ("- class: "+str(nametype)+" = "+str(y_true)+", prediction: "+str(y_pred))
    pickle.dump(list_y_true, open(folder+'list_y_true.data', 'wb'))
    pickle.dump(list_y_pred, open(folder+'list_y_pred_svm_prediction.data', 'wb'))
    return list_y_true, list_y_pred
    #
#---
folder = "C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/"
types = ["blues", "classical", "country", "disco", "hiphop", "metal", "pop", "reggae", "rock"]
a, b = extractMelSpectrogram_features(folder)
print ("#Load mel features:")
a = pickle.load(open(folder+'mel_features_svm_a.data', 'rb'))
b = pickle.load(open(folder+'mel_features_svm_b.data', 'rb'))
print ("#SVM:")
#default linear kernel
clf = svm.SVC()
clf = svm.SVC(kernel="rbf")
#training
clf.fit(a, b)
list_y_true, list_y_pred = getPrediction(folder, clf)
music_class = str(list_y_pred[0]) 
print(music_class)
#pickling the SVM
SVM_file_name = 'SVM.pkl'
SVM_model_pkl = open(SVM_file_name , 'wb')
pickle.dump(clf ,SVM_model_pkl)
SVM_model_pkl.close()
print("svm pickled")

#list_y_true = pickle.load(open(folder+'list_y_true.data', 'rb'))
#list_y_pred = pickle.load(open(folder+'list_y_pred_svm_prediction.data', 'rb'))

#print(classification_report(list_y_true, list_y_pred, target_names=types))
# Out:
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00000.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00001.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00002.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00003.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00004.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00005.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00006.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00007.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00008.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00009.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00010.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00011.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00012.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00013.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00014.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00015.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00016.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00017.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00018.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00019.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00020.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00021.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00022.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00023.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00024.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00025.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00026.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00027.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00028.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00029.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00030.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00031.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00032.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00033.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00034.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00035.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00036.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00037.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00038.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00039.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00040.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00041.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00042.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00043.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00044.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00045.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00046.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00047.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00048.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00049.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00050.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00051.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00052.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00053.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00054.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00055.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00056.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00057.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00058.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00059.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00060.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00061.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00062.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00063.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00064.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00065.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00066.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00067.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00068.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00069.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00070.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00071.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00072.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00073.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00074.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00075.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00076.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00077.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00078.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00079.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00080.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00081.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00082.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00083.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00084.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00085.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00086.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00087.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00088.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00089.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00090.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00091.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00092.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00093.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00094.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00095.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00096.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00097.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00098.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/blues/blues.00099.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00000.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00001.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00002.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00003.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00004.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00005.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00006.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00007.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00008.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00009.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00010.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00011.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00012.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00013.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00014.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00015.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00016.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00017.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00018.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00019.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00020.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00021.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00022.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00023.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00024.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00025.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00026.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00027.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00028.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00029.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00030.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00031.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00032.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00033.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00034.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00035.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00036.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00037.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00038.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00039.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00040.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00041.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00042.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00043.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00044.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00045.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00046.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00047.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00048.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00049.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00050.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00051.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00052.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00053.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00054.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00055.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00056.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00057.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00058.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00059.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00060.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00061.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00062.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00063.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00064.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00065.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00066.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00067.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00068.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00069.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00070.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00071.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00072.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00073.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00074.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00075.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00076.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00077.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00078.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00079.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00080.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00081.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00082.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00083.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00084.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00085.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00086.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00087.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00088.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00089.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00090.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00091.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00092.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00093.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00094.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00095.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00096.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00097.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00098.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/classical/classical.00099.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00000.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00001.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00002.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00003.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00004.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00005.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00006.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00007.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00008.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00009.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00010.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00011.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00012.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00013.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00014.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00015.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00016.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00017.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00018.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00019.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00020.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00021.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00022.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00023.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00024.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00025.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00026.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00027.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00028.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00029.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00030.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00031.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00032.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00033.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00034.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00035.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00036.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00037.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00038.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00039.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00040.wav
# -C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/country/country.00041.wav

# %%
import librosa.display
import scipy.io.wavfile as wavfile
import numpy
import os.path
from os import walk
from scipy import stats
import numpy as np
import librosa 
import numpy as np
from scipy.stats import norm
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix
folder = "C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/"

signal, rate = librosa.load("C:/Users/safab/Bureau/FlaskMusicClassifier/data/genres_original/rock/rock.00000.wav")  
 #The Mel Spectrogram
S = librosa.feature.melspectrogram(signal, sr=rate, n_fft=2048, hop_length=512, n_mels=128)
S_DB = librosa.power_to_db(S, ref=np.max)
S_DB = S_DB.flatten()[:1200]

clf = pickle.load(open('SVM.pkl' , 'rb'))
ans = clf.predict([S_DB])[0]
music_class = str(ans)
print(music_class)
